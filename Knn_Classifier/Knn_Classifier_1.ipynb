# %%
import pandas as pd
import numpy as np

# %%
class MyKNNClf: 
    def __init__(self, k=3): 
        self.k = k
    def __repr__(self): 
        return f'MyKNNClf class: k={self.k}'

# %%
model = MyKNNClf()

# %%
model
# Out:
# MyKNNClf class: k=34

# %%
print(model)
# Out:
# MyKNNClf class: k=34
