# %%
import pandas as pd
import numpy as np

# %%
# добавляем нашему классу метод fit

# %%
class MyKNNClf: 
    def __init__(self, k=3): 
        self.k = k
        self.train_size = None
    def __repr__(self): 
        return f'MyKNNClf class: k={self.k}'
