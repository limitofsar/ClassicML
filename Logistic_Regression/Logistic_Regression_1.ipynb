# %%
import pandas as pd 
import numpy as np 
from sklearn.datasets import make_classification

# %% [markdown]
# ### Инициализировали класс

# %%
class MyLogReg():
    def __init__(self, n_iter=10, learning_rate=0.1,):
        self.n_iter = n_iter 
        self.learning_rate = learning_rate
    def __repr__(self):
        return f'MyLogReg class: n_iter={self.n_iter}, learning_rate={self.learning_rate}'

# %%
model = MyLogReg(n_iter=90, learning_rate=0.2222)

# %%
print(model)
# Out:
# MyLogReg class: n_iter=90, learning_rate=0.2222

# %%
model
# Out:
# MyLogReg class: n_iter=90, learning_rate=0.2222
