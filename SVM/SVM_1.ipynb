# %%
import pandas as pd
import numpy as np

# %%
class MySVM():
    def __init__(self, n_iter=10, learning_rate=0.001):
        self.n_iter = n_iter
        self.learning_rate = learning_rate 
    def __repr__(self):
        return f'MySVM class: n_iter={self.n_iter}, learning_rate={self.learning_rate}'

# %%
model = MySVM()

# %%
model
# Out:
# MySVM class: n_iter=10, learning_rate=0.001

# %%
print(model)
# Out:
# MySVM class: n_iter=10, learning_rate=0.001
